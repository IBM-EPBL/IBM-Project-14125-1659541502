# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
#setting parameter for Image Data agumentation to the training data
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
#Image Data agumentation to the testing data
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale= 1./255,horizontal_flip = True,vertical_flip = True,zoom_range = 0.2)
test_datagen = ImageDataGenerator(rescale= 1./255)

# %%
#performing data agumentation to train data
x_train = train_datagen.flow_from_directory(
    r'/content/Nutrition Image Analysis using CNN and Rapid API/Dataset/TRAIN_SET',
    target_size=(64, 64),batch_size=5,color_mode='rgb',class_mode='sparse')
#performing data agumentation to test data
x_test = test_datagen.flow_from_directory(
    r'/content/Nutrition Image Analysis using CNN and Rapid API/Dataset/TEST_SET',
    target_size=(64, 64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 4118 images belonging to 5 classes.
# Found 929 images belonging to 5 classes.

# %%
# !pip install opencv.python

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)

# %%
import cv2

# %%
#imread is used to read the image

# %%
img = cv2.imread("/content/Nutrition Image Analysis using CNN and Rapid API/Dataset/TEST_SET/APPLES/n07740461_11121.jpg")

# %%
img = cv2.imread(r"/content/Nutrition Image Analysis using CNN and Rapid API/Dataset/TEST_SET/APPLES/n07740461_11121.jpg")

# %%
img
# Out:
# array([[[63, 50, 24],
#         [64, 51, 25],
#         [64, 50, 27],
#         ...,
#         [76, 62, 40],
#         [75, 62, 40],
#         [75, 62, 40]],
#
#        [[64, 51, 25],
#         [64, 51, 25],
#         [64, 50, 27],
#         ...,
#         [77, 63, 41],
#         [76, 63, 41],
#         [76, 63, 41]],
#
#        [[64, 51, 25],
#         [64, 51, 25],
#         [63, 50, 24],
#         ...,
#         [77, 63, 41],
#         [75, 62, 40],
#         [75, 62, 40]],
#
#        ...,
#
#        [[ 3,  1,  1],
#         [ 2,  0,  0],
#         [ 0,  0,  0],
#         ...,
#         [ 2,  0, 46],
#         [ 1,  1, 49],
#         [ 1,  0, 50]],
#
#        [[ 6,  4,  4],
#         [ 3,  1,  1],
#         [ 2,  0,  0],
#         ...,
#         [ 0,  0, 46],
#         [ 1,  1, 49],
#         [ 2,  1, 51]],
#
#        [[11,  6,  7],
#         [ 5,  3,  3],
#         [ 2,  0,  0],
#         ...,
#         [ 0,  0, 46],
#         [ 1,  1, 49],
#         [ 0,  1, 51]]], dtype=uint8)

# %%
img.ndim
# Out:
# 3

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img_flag = cv2.imread(r"/content/Nutrition Image Analysis using CNN and Rapid API/Dataset/TEST_SET/APPLES/n07740461_11121.jpg")

# %%
img_flag
# Out:
# array([[[63, 50, 24],
#         [64, 51, 25],
#         [64, 50, 27],
#         ...,
#         [76, 62, 40],
#         [75, 62, 40],
#         [75, 62, 40]],
#
#        [[64, 51, 25],
#         [64, 51, 25],
#         [64, 50, 27],
#         ...,
#         [77, 63, 41],
#         [76, 63, 41],
#         [76, 63, 41]],
#
#        [[64, 51, 25],
#         [64, 51, 25],
#         [63, 50, 24],
#         ...,
#         [77, 63, 41],
#         [75, 62, 40],
#         [75, 62, 40]],
#
#        ...,
#
#        [[ 3,  1,  1],
#         [ 2,  0,  0],
#         [ 0,  0,  0],
#         ...,
#         [ 2,  0, 46],
#         [ 1,  1, 49],
#         [ 1,  0, 50]],
#
#        [[ 6,  4,  4],
#         [ 3,  1,  1],
#         [ 2,  0,  0],
#         ...,
#         [ 0,  0, 46],
#         [ 1,  1, 49],
#         [ 2,  1, 51]],
#
#        [[11,  6,  7],
#         [ 5,  3,  3],
#         [ 2,  0,  0],
#         ...,
#         [ 0,  0, 46],
#         [ 1,  1, 49],
#         [ 0,  1, 51]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img_flag)

# %%
resized_img = cv2.resize(img,(200,200))

# %%
resized_img.shape
# Out:
# (200, 200, 3)

# %%
plt.imshow(resized_img)

# %%
cv_img = cv2.cvtColor(img,cv2.COLOR_BGR2YCR_CB)

# %%
plt.imshow(cv_img)

# %%
cv_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv_img)

# %%
roi_img = img[50:280,35:150]
roi_img = img[10:40,35:150]

# %%
plt.imshow(roi_img)

# %%
roi_img = img[10:40,0:90]

# %%
plt.imshow(roi_img)

# %%
roi_img = img[0:90,10:40]

# %%
plt.imshow(roi_img)

# %%
img_bl = cv2.blur(img,(10,10))

# %%
plt.imshow(img_bl)

# %%
img_gbl = cv2.GaussianBlur(img,(5,5),0)

# %%
plt.imshow(img_gbl)

# %%
img_edge = cv2.Canny(img,230,350)

# %%
plt.imshow(img_edge)

# %%
thresh, thresh_img = cv2.threshold(img, 200, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_img)

# %%
circle = cv2.circle(img,(300,200),60,(255,0,0),5)

# %%
plt.imshow(img)

# %%
rectangle = cv2.rectangle(img,(200,100),(400,300),(0,0,255),10)

# %%
plt.imshow(img)

# %%
line = cv2.line(img,(200,100),(400,300),(0,255,0),3)

# %%
plt.imshow(img)

# %%
line = cv2.line(img,(100,50),(200,150),(0,150,0),3)

# %%
plt.imshow(img)

# %%
line = cv2.line(img,(50,25),(100,75),(0,75,0),3)

# %%
plt.imshow(img)

# %%
text = cv2.putText(img,"Opencv",(50,25),cv2.FONT_HERSHEY_SIMPLEX,2,(100,100,100),5)

# %%
plt.imshow(img)
